# %%
# !pip install langchain langchain-community langgraph chromadb pypdf sentence-transformers transformers accelerate -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 54.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 39.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.3/336.3 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 35.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.4/542.4 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 39.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.2/180.2 kB 12.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 5.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ae0d98cb-318b-4a39-b347-56b6e54ce053" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae0d98cb-318b-4a39-b347-56b6e54ce053">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install unstructured -q

# %%
# !pip install pdfminer.six -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 42.4 MB/s eta 0:00:00

# %%
from langchain_community.document_loaders import UnstructuredWordDocumentLoader

# Install pi_heif as it's a dependency for unstructured to process certain image formats in PDFs
# !pip install pi_heif -q
# !pip install unstructured-inference -q
# !pip install pdf2image -q
# !pip install unstructured-pytesseract -q
# !apt-get install poppler-utils -y -q

# Install python-docx to handle .docx files
# !pip install python-docx -q

loader = UnstructuredWordDocumentLoader("/content/Customer Support Knowledge Base.docx")
documents = loader.load()

print("Pages:", len(documents))
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# poppler-utils is already the newest version (22.02.0-2ubuntu0.12).
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 10.7 MB/s eta 0:00:00
# Pages: 1

# %%
# !pip install unstructured -q

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

chunks = text_splitter.split_documents(documents)
print("Chunks:", len(chunks))
# Out:
# Chunks: 2

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2"
)
# Out:
# /tmp/ipykernel_3947/818555509.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
from langchain_community.vectorstores import Chroma

vectorstore = Chroma.from_documents(
    chunks,
    embedding_model
)

retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

# %%
from transformers import pipeline

llm_pipeline = pipeline(
    "text-generation",
    model="google/flan-t5-base"
)

def local_llm(prompt):
    result = llm_pipeline(prompt, max_length=200)
    return result[0]["generated_text"]
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# ...

# %%
def process_query(state):
    query = state["query"]

    # Retrieve relevant chunks
    docs = retriever.invoke(query)

    if not docs:
        return {
            "query": query,
            "response": "No relevant information found.",
            "confidence": 0.2
        }

    context = "\n".join([doc.page_content for doc in docs])

    prompt = f"""
    You are a customer support assistant.
    Answer ONLY using the context below.

    Context:
    {context}

    Question:
    {query}
    """

    answer = local_llm(prompt)

    # Confidence logic
    confidence = 0.9 if len(docs) > 0 else 0.3

    return {
        "query": query,
        "response": answer,
        "confidence": confidence
    }

# %%
def route_decision(state):
    if state["confidence"] < 0.6:
        return "escalate"
    return "answer"

# %%
def human_node(state):
    print("\n⚠️ Escalation Triggered")
    print("Query:", state["query"])

    human_answer = input("Enter human response: ")

    return {
        "response": human_answer,
        "confidence": 1.0,
        "escalated": True
    }

# %%
def output_node(state):
    print("\n✅ Final Answer:")
    print(state["response"])
    return state

# %%
from langgraph.graph import StateGraph

class GraphState(dict):
    pass

builder = StateGraph(GraphState)

# Nodes
builder.add_node("process", process_query)
builder.add_node("hitl", human_node)
builder.add_node("output", output_node)

# Entry
builder.set_entry_point("process")

# Conditional routing
builder.add_conditional_edges(
    "process",
    route_decision,
    {
        "answer": "output",
        "escalate": "hitl"
    }
)

# HITL → Output
builder.add_edge("hitl", "output")

graph = builder.compile()

# %%
from typing import TypedDict

class GraphState(TypedDict, total=False):
    query: str
    response: str
    confidence: float
    escalated: bool

# %%
def process_query(state):
    query = state.get("query", "")

    if not query:
        return {
            "response": "Invalid query",
            "confidence": 0.0
        }

    docs = retriever.invoke(query)

    if not docs:
        return {
            "query": query,
            "response": "No relevant information found.",
            "confidence": 0.2
        }

    context = "\n".join([doc.page_content for doc in docs])

    prompt = f"""
    Answer using ONLY the context below.

    Context:
    {context}

    Question:
    {query}
    """

    answer = local_llm(prompt)

    return {
        "query": query,
        "response": answer,
        "confidence": 0.9
    }

# %%
def route_decision(state):
    confidence = state.get("confidence", 0)

    if confidence < 0.6:
        return "escalate"
    return "answer"

# %%
def human_node(state):
    print("\n⚠️ Escalation Triggered")
    print("Query:", state.get("query", ""))

    human_answer = input("Enter human response: ")

    return {
        "query": state.get("query", ""),
        "response": human_answer,
        "confidence": 1.0,
        "escalated": True
    }

# %%
def output_node(state):
    print("\n✅ Final Answer:")
    print(state.get("response", "No response"))
    return state

# %%
from langgraph.graph import StateGraph

builder = StateGraph(GraphState)

builder.add_node("process", process_query)
builder.add_node("hitl", human_node)
builder.add_node("output", output_node)

builder.set_entry_point("process")

builder.add_conditional_edges(
    "process",
    route_decision,
    {
        "answer": "output",
        "escalate": "hitl"
    }
)

builder.add_edge("hitl", "output")

graph = builder.compile()

# %%
while True:
    query = input("\nAsk your question (type 'exit'): ")

    if query.lower() == "exit":
        break

    graph.invoke({
        "query": query,
        "response": "",
        "confidence": 0.0
    })
# Out:
# Ask your question (type 'exit'): Refund Policy
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ✅ Final Answer:
#
#     Answer using ONLY the context below.
#
#     Context:
#     Customer Support Knowledge Base
#
# 1. Refund Policy
#
# Customers can request a refund within 7 days of purchase. Refunds will be processed within 5 working days.
#
# 2. Cancellation Policy
#
# Orders can be cancelled before shipping. Once shipped, cancellation is not allowed.
#
# 3. Delivery Policy
#
# Orders are delivered within 5-7 business days.
#
# ...
